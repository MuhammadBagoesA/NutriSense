# %%
import pandas as pd

# %%
df = pd.read_csv('recipe_final.csv')
df.head()
# Out:
#    Unnamed: 0  recipe_id                        recipe_name  aver_rate  \
# 0           0     222388                     Homemade Bacon       5.00
# 1           1     240488  Pork Loin, Apples, and Sauerkraut       4.76
# 2           2     218939   Foolproof Rosemary Chicken Wings       4.57
# 3           3      87211              Chicken Pesto Paninis       4.62
# 4           4     245714                 Potato Bacon Pizza       4.50
#
#                                            image_url  review_nums  calories  \
# 0  https://images.media-allrecipes.com/userphotos...            3        15
# 1  https://images.media-allrecipes.com/userphotos...           29        19
# 2  https://images.media-allrecipes.com/userphotos...           12        17
# 3  https://images.media-allrecipes.com/userphotos...          163        32
# 4  https://images.media-allrecipes.com/userphotos...            2         8
#
#    fat  carbohydrates  protein  cholesterol  sodium  fiber  \
# ...

# %%
len(df)
# Out:
# 48735

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

# %%
import pandas as pd

# Load dataset
file_path = 'recipe_final.csv'
recipe_df = pd.read_csv(file_path)

recipe_df.head()
# Out:
#    Unnamed: 0  recipe_id                        recipe_name  aver_rate  \
# 0           0     222388                     Homemade Bacon       5.00
# 1           1     240488  Pork Loin, Apples, and Sauerkraut       4.76
# 2           2     218939   Foolproof Rosemary Chicken Wings       4.57
# 3           3      87211              Chicken Pesto Paninis       4.62
# 4           4     245714                 Potato Bacon Pizza       4.50
#
#                                            image_url  review_nums  calories  \
# 0  https://images.media-allrecipes.com/userphotos...            3        15
# 1  https://images.media-allrecipes.com/userphotos...           29        19
# 2  https://images.media-allrecipes.com/userphotos...           12        17
# 3  https://images.media-allrecipes.com/userphotos...          163        32
# 4  https://images.media-allrecipes.com/userphotos...            2         8
#
#    fat  carbohydrates  protein  cholesterol  sodium  fiber  \
# ...

# %%
len(recipe_df)
# Out:
# 48735

# %%
# Normalisasi data numerik
scaler = StandardScaler()
X_numerical = scaler.fit_transform(recipe_df[['protein', 'carbohydrates', 'fat', 'fiber']])

# %%
knn = NearestNeighbors(n_neighbors=5, metric='euclidean')
knn.fit(X_numerical)
# Out:
# NearestNeighbors(metric='euclidean')

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline

# Function to Recommend Recipes
def recommend_recipes():
    #gizi sesuai PERATURAN MENTERI KESEHATAN REPUBLIK INDONESIA
    #               protein, karbo, fat,  fiber
    data_nutrisi = [18.3,   93.3,  21.7, 9]
    
    # merekomendasikan 5000 resep paling mendekati nilai gizi
    input_features_scaled = scaler.transform([data_nutrisi])
    distances, indices = knn.kneighbors(input_features_scaled, n_neighbors=5000)
    recommendations = recipe_df.iloc[indices[0]]

    return indices[0]

selected_data = recommend_recipes()
print(selected_data)
# Out:
# [19591 11552  4780 ... 22652 25762 19176]
# c:\Users\ergik\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
type(selected_data)
# Out:
# numpy.ndarray

# %%
dataset_tereduksi = df.loc[selected_data].reset_index(drop=True)
dataset_tereduksi.head()
# Out:
#    Unnamed: 0  recipe_id                                   recipe_name  \
# 0       19591     245720                              Churro Log Cabin
# 1       11552     247451                    Pulled BBQ Chicken Sliders
# 2        4780     232860  Easy Tasty Ham Steaks with Maple Glaze For 2
# 3       24585     245028                    Poached Pears Belle Helene
# 4       20998     232909                            American Flag Cake
#
#    aver_rate                                          image_url  review_nums  \
# 0       5.00  http://images.media-allrecipes.com/userphotos/...            1
# 1       4.17  https://images.media-allrecipes.com/userphotos...            5
# 2       4.62  https://images.media-allrecipes.com/userphotos...           19
# 3       5.00  http://images.media-allrecipes.com/userphotos/...            7
# 4       4.22  http://images.media-allrecipes.com/userphotos/...           38
#
#    calories  fat  carbohydrates  protein  cholesterol  sodium  fiber  \
# ...

# %%
dataset_tereduksi.to_csv("reduced_dataset.csv", index=False)
